# %%
from sklearn import metrics
from skimage import io
import matplotlib.pyplot as plt
from osgeo import gdal
import numpy as np
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

import pandas as pd
import glob
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Medidas Imagen

# %%
def leerc(file):
  filcs = pd.read_csv(file)
  print('Archivo Cargado ',file)
  print(filcs.head())
  y_ref = np.array(filcs['Classified'])
  print(y_ref)
  print(len(y_ref))
  y_pred = np.array(filcs['Thematic_C'])
  print(y_pred)
  print(len(y_pred))
  return y_ref, y_pred

# %% [markdown]
# Matriz Confusion

# %%
def mconfk(y_ref, y_pred,fecha):
  from sklearn.metrics import confusion_matrix
  m_conf = confusion_matrix(y_ref, y_pred,labels=[0,1])
  print(m_conf)
  total = np.sum(m_conf)
  N = total
  p0 = np.sum(np.diag(m_conf)) / N
  pc = np.sum(np.sum(m_conf, axis=0) * np.sum(m_conf, axis=1)) / N ** 2
  kappa = (p0 - pc) / (1 - pc)
  print('Kappa: ', round(kappa,3))
  data = {'y_Actual':    y_ref,
          'y_Predicted': y_pred
          }

  df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
  confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
  plt.figure(figsize=(6,5))
  fig, ax = plt.subplots(figsize=(6, 5))
  index = ['Mineria','No Mineria']  
  columns = ['Mineria','No Mineria',]

  sns.heatmap(confusion_matrix, annot=True, fmt='g', ax=ax, cmap='rocket_r');  #annot=True to annotate cells, ftm='g' to disable scientific notation

  # labels, title and ticks
  ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
  ax.set_title('Matriz Confusión - '+str(fecha)); 
  ax.xaxis.set_ticklabels(index); ax.yaxis.set_ticklabels(columns);

  fig.show()
  fig.tight_layout()
  ruta = "/content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Graficas/"
  fig.savefig(ruta+'/Mconfusion_'+str(fecha)+'.png', dpi=300)

  #Exactitud Productor
  tot_c0 = sum(m_conf[:,0])
  tot_c1 = sum(m_conf[:,1])
  val_c0 = m_conf[0,0]
  val_c1 = m_conf[1,1]
  exac_pr = [val_c0/tot_c0, val_c1/tot_c1]
  print('Exactitud Productor: ', exac_pr)

  #Exactitud Usuario
  tot_c0 = sum(m_conf[0,:])
  tot_c1 = sum(m_conf[1,:])
  val_c0 = m_conf[0,0]
  val_c1 = m_conf[1,1]
  exac_us = [val_c0/tot_c0, val_c1/tot_c1]
  print('Exactitud Usuario: ',exac_us)

  return kappa, confusion_matrix, exac_pr, exac_us

# %% [markdown]
# Otras Medidas

# %%
def otmedidas(y_ref, y_pred):
  # Accuracy
  accu_s = accuracy_score(y_ref, y_pred)
  print('Exactitud General: ',accu_s)

  # Recall
  rcall_s = recall_score(y_ref, y_pred, average=None)
  print('Sensibilidad: ',rcall_s)

  # Precision
  pr_s = precision_score(y_ref, y_pred, average=None)
  print('Precision: ',pr_s)

  # F1 Score
  f1_s = f1_score(y_ref, y_pred, average=None)
  print('F1_Score: ', f1_s)

  return accu_s, rcall_s, pr_s, f1_s

# %%
fechas = [201710,201712,201803,201806,201812,201902,201908,201911]
rutam = f"/content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/"
for i in fechas:
  muestreoi = rutam + "MuestreoClasificacion_" + str(i) + ".csv"
  y_ref, y_pred = leerc(muestreoi)
  kappa, confusion_matrix, exac_pr, exac_us = mconfk(y_ref, y_pred, i)
  accu_s, rcall_s, pr_s, f1_s = otmedidas(y_ref, y_pred)
  f = open("/content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/Resultados.txt", "a")
  f.write('-------MEDIDAS FECHA: '+ str(i) + '------- \n')
  f.write('Matriz de confusion \n')
  f.write(str(confusion_matrix)+'\n')
  f.write('Kappa: '+ str(round(kappa,3))+'\n')
  f.write('Exactitud Productor: '+ str(np.around(np.array(exac_pr), 3))+'\n')
  f.write('Exactitud Usuario: '+ str(np.around(np.array(exac_us), 3))+'\n')
  f.write('Exactitud General: '+ str(round(accu_s,3)) +'\n')
  f.write('Recall: '+ str(np.around(np.array(rcall_s), 3)) +'\n')
  f.write('Precision: '+ str(np.around(np.array(pr_s), 3)) +'\n')
  f.write('F1-Score: '+ str(np.around(np.array(f1_s), 3)) +'\n')
  f.write('\n \n')

f.close()
# Out:
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201710.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1  NoMineria           1           1   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4    Mineria           0           0   Yes
# 4    4   5  NoMineria           1           1   Yes
# [1 1 1 ... 1 1 1]
# 2000
# [1 1 1 ... 1 1 1]
# 2000
# [[ 447   11]
#  [  12 1530]]
# Kappa:  0.967
# Exactitud Productor:  [0.9738562091503268, 0.9928617780661908]
# Exactitud Usuario:  [0.9759825327510917, 0.9922178988326849]
# Exactitud General:  0.9885
# Sensibilidad:  [0.97598253 0.9922179 ]
# Precision:  [0.97385621 0.99286178]
# F1_Score:  [0.97491821 0.99253973]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201712.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1  NoMineria           1           1   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4  NoMineria           1           1   Yes
# 4    4   5    Mineria           0           0   Yes
# [1 1 1 ... 1 0 0]
# 2000
# [1 1 1 ... 1 0 0]
# 2000
# [[ 444    3]
#  [  17 1536]]
# Kappa:  0.972
# Exactitud Productor:  [0.9631236442516269, 0.9980506822612085]
# Exactitud Usuario:  [0.9932885906040269, 0.9890534449452673]
# Exactitud General:  0.99
# Sensibilidad:  [0.99328859 0.98905344]
# Precision:  [0.96312364 0.99805068]
# F1_Score:  [0.97797357 0.99353169]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201803.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1    Mineria           0           0   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4  NoMineria           1           1   Yes
# 4    4   5  NoMineria           1           1   Yes
# [0 1 1 ... 0 1 1]
# 2000
# [0 1 1 ... 0 1 1]
# 2000
# [[ 477    9]
#  [  20 1494]]
# Kappa:  0.961
# Exactitud Productor:  [0.959758551307847, 0.9940119760479041]
# Exactitud Usuario:  [0.9814814814814815, 0.9867899603698811]
# Exactitud General:  0.9855
# Sensibilidad:  [0.98148148 0.98678996]
# Precision:  [0.95975855 0.99401198]
# F1_Score:  [0.97049847 0.9903878 ]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201806.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1  NoMineria           1           1   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4  NoMineria           1           1   Yes
# 4    4   5  NoMineria           1           1   Yes
# [1 1 1 ... 1 1 1]
# 2000
# [1 1 1 ... 1 1 1]
# 2000
# [[ 520   11]
#  [  17 1452]]
# Kappa:  0.964
# Exactitud Productor:  [0.9683426443202979, 0.9924812030075187]
# Exactitud Usuario:  [0.9792843691148776, 0.988427501701838]
# Exactitud General:  0.986
# Sensibilidad:  [0.97928437 0.9884275 ]
# Precision:  [0.96834264 0.9924812 ]
# F1_Score:  [0.97378277 0.9904502 ]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201812.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1    Mineria           0           0   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4  NoMineria           1           1   Yes
# 4    4   5  NoMineria           1           1   Yes
# [0 1 1 ... 1 1 1]
# 2000
# [0 1 1 ... 1 1 1]
# 2000
# [[ 443   10]
#  [  19 1528]]
# Kappa:  0.959
# Exactitud Productor:  [0.9588744588744589, 0.9934980494148244]
# Exactitud Usuario:  [0.977924944812362, 0.9877181641887525]
# Exactitud General:  0.9855
# Sensibilidad:  [0.97792494 0.98771816]
# Precision:  [0.95887446 0.99349805]
# F1_Score:  [0.96830601 0.99059968]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201902.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1  NoMineria           1           1   Yes
# 1    1   2    Mineria           0           0   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4    Mineria           0           0   Yes
# 4    4   5  NoMineria           1           1   Yes
# [1 0 1 ... 1 1 1]
# 2000
# [1 0 1 ... 1 1 1]
# 2000
# [[ 473    7]
#  [  19 1501]]
# Kappa:  0.965
# Exactitud Productor:  [0.9613821138211383, 0.9953580901856764]
# Exactitud Usuario:  [0.9854166666666667, 0.9875]
# Exactitud General:  0.987
# Sensibilidad:  [0.98541667 0.9875    ]
# Precision:  [0.96138211 0.99535809]
# F1_Score:  [0.97325103 0.99141347]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201908.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1  NoMineria           1           1   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3  NoMineria           1           1   Yes
# 3    3   4  NoMineria           1           1   Yes
# 4    4   5  NoMineria           1           1   Yes
# [1 1 1 ... 1 1 0]
# 2000
# [1 1 1 ... 1 1 0]
# 2000
# [[ 487    6]
#  [  10 1497]]
# Kappa:  0.979
# Exactitud Productor:  [0.9798792756539235, 0.9960079840319361]
# Exactitud Usuario:  [0.9878296146044625, 0.993364299933643]
# Exactitud General:  0.992
# Sensibilidad:  [0.98782961 0.9933643 ]
# Precision:  [0.97987928 0.99600798]
# F1_Score:  [0.98383838 0.99468439]
# Archivo Cargado  /content/gdrive/MyDrive/Mineria_Planet/modelos/Validacion/Muestreo/MuestreoClasificacion_201911.csv
#    FID  ID Class_Name  Classified  Thematic_C Match
# 0    0   1    Mineria           0           0   Yes
# 1    1   2  NoMineria           1           1   Yes
# 2    2   3    Mineria           0           0   Yes
# 3    3   4    Mineria           0           0   Yes
# 4    4   5    Mineria           0           0   Yes
# [0 1 0 ... 1 1 1]
# 2000
# [0 1 0 ... 1 1 1]
# 2000
# [[ 487    7]
#  [  17 1489]]
# Kappa:  0.968
# Exactitud Productor:  [0.9662698412698413, 0.9953208556149733]
# Exactitud Usuario:  [0.9858299595141701, 0.9887118193891102]
# Exactitud General:  0.988
# Sensibilidad:  [0.98582996 0.98871182]
# Precision:  [0.96626984 0.99532086]
# F1_Score:  [0.9759519  0.99200533]

# %%
lista = [0.55984556,0.69974569]
np_array = np.array(lista)
np_round_to_tenths = np.around(np_array, 3)
print(np_round_to_tenths)
# Out:
# [0.56 0.7 ]

# %%
print('lista es: '+str(lista))
# Out:
# lista es: [0.55984556, 0.69974569]
